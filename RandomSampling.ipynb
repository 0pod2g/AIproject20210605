# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
data = pd.read_csv('C:\\Users\\pod2g\\Desktop\\weatherAUS.csv')
df = data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# Cloud9am        89572.0     4.447461   2.887159    0.0     1.0     5.0
# Cloud3pm        86102.0     4.509930   2.720357    0.0     2.0     5.0
# Temp9am        143693.0    16.990631   6.488753   -7.2    12.3    16.7
# Temp3pm        141851.0    21.683390   6.936650   -5.4    16.6    21.1
#
#                   75%     max
# MinTemp          16.9    33.9
# MaxTemp          28.2    48.1
# Rainfall          0.8   371.0
# Evaporation       7.4   145.0
# Sunshine         10.6    14.5
# WindGustSpeed    48.0   135.0
# WindSpeed9am     19.0   130.0
# WindSpeed3pm     24.0    87.0
# Humidity9am      83.0   100.0
# Humidity3pm      66.0   100.0
# Pressure9am    1022.4  1041.0
# Pressure3pm    1020.0  1039.6
# Cloud9am          7.0     9.0
# Cloud3pm          7.0     9.0
# Temp9am          21.6    40.2
# Temp3pm          26.4    46.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
((df.isnull().sum())/len(df))*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
df = df.drop(['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], axis = 1) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   WindGustDir    135134 non-null  object
#  6   WindGustSpeed  135197 non-null  float64
#  7   WindDir9am     134894 non-null  object
#  8   WindDir3pm     141232 non-null  object
#  9   WindSpeed9am   143693 non-null  float64
#  10  WindSpeed3pm   142398 non-null  float64
#  11  Humidity9am    142806 non-null  float64
#  12  Humidity3pm    140953 non-null  float64
#  13  Pressure9am    130395 non-null  float64
#  14  Pressure3pm    130432 non-null  float64
#  15  Temp9am        143693 non-null  float64
#  16  Temp3pm        141851 non-null  float64
#  17  RainToday      142199 non-null  object
#  18  RainTomorrow   142193 non-null  object
# dtypes: float64(12), object(7)
# memory usage: 21.1+ MB

# %%
df_num = df.select_dtypes('float64')
df_obj = df.select_dtypes('object')

# %%
numeric_null = df_num.isnull().sum() 
numeric_null
# Out:
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# WindGustSpeed    10263
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Temp9am           1767
# Temp3pm           3609
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'median') 
df_num = pd.DataFrame(imputer.fit_transform(df_num), columns = df_num.columns)
obj_imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
df_obj = pd.DataFrame(obj_imputer.fit_transform(df_obj), columns = df_obj.columns)
df_new = pd.concat([df_obj, df_num], axis = 1, join = 'inner') 
df_new
# Out:
#               Date Location WindGustDir WindDir9am WindDir3pm RainToday  \
# 0       2008-12-01   Albury           W          W        WNW        No
# 1       2008-12-02   Albury         WNW        NNW        WSW        No
# 2       2008-12-03   Albury         WSW          W        WSW        No
# 3       2008-12-04   Albury          NE         SE          E        No
# 4       2008-12-05   Albury           W        ENE         NW        No
# ...            ...      ...         ...        ...        ...       ...
# 145455  2017-06-21    Uluru           E         SE        ENE        No
# 145456  2017-06-22    Uluru         NNW         SE          N        No
# 145457  2017-06-23    Uluru           N         SE        WNW        No
# 145458  2017-06-24    Uluru          SE        SSE          N        No
# 145459  2017-06-25    Uluru           W        ESE        ESE        No
#
#        RainTomorrow  MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0                No     13.4     22.9       0.6           44.0          20.0
# 1                No      7.4     25.1       0.0           44.0           4.0
# 2                No     12.9     25.7       0.0           46.0          19.0
# 3                No      9.2     28.0       0.0           24.0          11.0
# 4                No     17.5     32.3       1.0           41.0           7.0
# ...             ...      ...      ...       ...            ...           ...
# 145455           No      2.8     23.4       0.0           31.0          13.0
# 145456           No      3.6     25.3       0.0           22.0          13.0
# 145457           No      5.4     26.9       0.0           37.0           9.0
# 145458           No      7.8     27.0       0.0           28.0          13.0
# 145459           No     14.9     22.6       0.0           39.0          17.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               24.0         71.0         22.0       1007.7       1007.1
# 1               22.0         44.0         25.0       1010.6       1007.8
# 2               26.0         38.0         30.0       1007.6       1008.7
# 3                9.0         45.0         16.0       1017.6       1012.8
# 4               20.0         82.0         33.0       1010.8       1006.0
# ...              ...          ...          ...          ...          ...
# 145455          11.0         51.0         24.0       1024.6       1020.3
# 145456           9.0         56.0         21.0       1023.5       1019.1
# 145457           9.0         53.0         24.0       1021.0       1016.8
# 145458           7.0         51.0         24.0       1019.4       1016.5
# 145459          17.0         62.0         36.0       1020.2       1017.9
#
#         Temp9am  Temp3pm
# 0          16.9     21.8
# 1          17.2     24.3
# 2          21.0     23.2
# 3          18.1     26.5
# 4          17.8     29.7
# ...         ...      ...
# 145455     10.1     22.4
# 145456     10.9     24.5
# 145457     12.5     26.1
# 145458     15.1     26.0
# 145459     15.0     20.9
#
# [145460 rows x 19 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   WindGustDir    145460 non-null  object
#  3   WindDir9am     145460 non-null  object
#  4   WindDir3pm     145460 non-null  object
#  5   RainToday      145460 non-null  object
#  6   RainTomorrow   145460 non-null  object
#  7   MinTemp        145460 non-null  float64
#  8   MaxTemp        145460 non-null  float64
#  9   Rainfall       145460 non-null  float64
#  10  WindGustSpeed  145460 non-null  float64
#  11  WindSpeed9am   145460 non-null  float64
#  12  WindSpeed3pm   145460 non-null  float64
#  13  Humidity9am    145460 non-null  float64
#  14  Humidity3pm    145460 non-null  float64
#  15  Pressure9am    145460 non-null  float64
#  16  Pressure3pm    145460 non-null  float64
#  17  Temp9am        145460 non-null  float64
#  18  Temp3pm        145460 non-null  float64
# dtypes: float64(12), object(7)
# memory usage: 21.1+ MB

# %%
df_num = df_new.select_dtypes('float64')
df_obj = df_new.select_dtypes('object')

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
data_std = scaler.fit_transform(df_num) 
data_std
# Out:
# array([[ 0.18975691, -0.0445749 , -0.20358073, ..., -1.22301167,
#         -0.01350553,  0.0191346 ],
#        [-0.75278601,  0.26579424, -0.27509664, ..., -1.1179692 ,
#          0.03301131,  0.3840643 ],
#        [ 0.11121166,  0.35044037, -0.27509664, ..., -0.9829146 ,
#          0.62222462,  0.22349523],
#        ...,
#        [-1.06696699,  0.51973264, -0.27509664, ...,  0.23257682,
#         -0.69575252,  0.64681369],
#        [-0.68994982,  0.53384032, -0.27509664, ...,  0.18755862,
#         -0.29260657,  0.6322165 ],
#        [ 0.42539264, -0.08689797, -0.27509664, ...,  0.39764355,
#         -0.30811219, -0.11224009]])

# %%
cov_matrix = np.cov(data_std.T) 
cov_matrix
# Out:
# array([[ 1.00000687,  0.73336261,  0.10233946,  0.17190036,  0.17351408,
#          0.17305611, -0.23131168,  0.00611145, -0.42330195, -0.43282703,
#          0.89783543,  0.69857911],
#        [ 0.73336261,  1.00000687, -0.0735633 ,  0.06645098,  0.01438959,
#          0.04950688, -0.49835335, -0.49872832, -0.30805909, -0.39634168,
#          0.87934082,  0.96833848],
#        [ 0.10233946, -0.0735633 ,  1.00000687,  0.12510969,  0.08458634,
#          0.05568874,  0.22066277,  0.2479474 , -0.15881311, -0.11939752,
#          0.01093349, -0.07746648],
#        [ 0.17190036,  0.06645098,  0.12510969,  1.00000687,  0.57874771,
#          0.65797906, -0.20880423, -0.02680457, -0.4258224 , -0.38414264,
#          0.1457175 ,  0.03237484],
#        [ 0.17351408,  0.01438959,  0.08458634,  0.57874771,  1.00000687,
#          0.51228234, -0.26819801, -0.03107938, -0.21510871, -0.16512523,
#          0.12749145,  0.0048057 ],
#        [ 0.17305611,  0.04950688,  0.05568874,  0.65797906,  0.51228234,
#          1.00000687, -0.14335892,  0.01627471, -0.2772787 , -0.23927534,
#          0.16104064,  0.02752925],
#        [-0.23131168, -0.49835335,  0.22066277, -0.20880423, -0.26819801,
#         -0.14335892,  1.00000687,  0.65929433,  0.13141858,  0.17591516,
#         -0.46977733, -0.49124508],
#        [ 0.00611145, -0.49872832,  0.2479474 , -0.02680457, -0.03107938,
#          0.01627471,  0.65929433,  1.00000687, -0.02598626,  0.04852704,
#         -0.21695208, -0.55561023],
#        [-0.42330195, -0.30805909, -0.15881311, -0.4258224 , -0.21510871,
#         -0.2772787 ,  0.13141858, -0.02598626,  1.00000687,  0.95966926,
#         -0.39688783, -0.26502747],
#        [-0.43282703, -0.39634168, -0.11939752, -0.38414264, -0.16512523,
#         -0.23927534,  0.17591516,  0.04852704,  0.95966926,  1.00000687,
#         -0.44118708, -0.36008594],
#        [ 0.89783543,  0.87934082,  0.01093349,  0.1457175 ,  0.12749145,
#          0.16104064, -0.46977733, -0.21695208, -0.39688783, -0.44118708,
#          1.00000687,  0.84562813],
#        [ 0.69857911,  0.96833848, -0.07746648,  0.03237484,  0.0048057 ,
#          0.02752925, -0.49124508, -0.55561023, -0.26502747, -0.36008594,
#          0.84562813,  1.00000687]])

# %%
eig_vals, eig_vec = np.linalg.eig(cov_matrix) 

print(eig_vals)  
print('')
print(eig_vec)
# Out:
# [4.62952056 2.45298232 1.68265001 1.05382879 0.80453769 0.52218269
#  0.3454097  0.29969981 0.11384832 0.03890918 0.02604204 0.03047139]
#
# [[ 0.37177791  0.01314843  0.2740417  -0.34829873 -0.21436557 -0.13042834
#    0.0639653  -0.0673844   0.67168006 -0.37239165  0.05385982 -0.02950512]
#  [ 0.41084155  0.245087    0.05642969 -0.09388456  0.01275345  0.14009131
#   -0.19307083 -0.04011965 -0.3912683  -0.12195092  0.55740342 -0.47096424]
#  [-0.00130526 -0.23206061  0.32099916 -0.31430575  0.85140183  0.06742633
#    0.10221674  0.06344827 -0.01317496 -0.00917082  0.01213601  0.0027021 ]
#  [ 0.17662719 -0.4590421  -0.26909435 -0.02853911  0.01467385  0.22091827
#   -0.05547803 -0.79457213 -0.00816956  0.01786688 -0.01706906  0.02714277]
#  [ 0.13622833 -0.36951024 -0.35828009 -0.26909991  0.01778365 -0.62636512
#   -0.43168844  0.23254172 -0.09921921  0.02723167  0.02000373  0.00764133]
#  [ 0.14780502 -0.41182975 -0.28560798 -0.20870695 -0.18954227  0.58310316
#    0.18986932  0.51886359 -0.00409943 -0.04433669  0.00141856 -0.01514973]
#  [-0.2750666  -0.15030438  0.44081648 -0.11775235 -0.18953224  0.30873216
#   -0.70282829  0.01680286  0.10283423  0.22147978  0.06468203  0.06528605]
#  [-0.19592152 -0.29812832  0.44140563 -0.26954046 -0.37038452 -0.20029686
#    0.3157368  -0.09520279 -0.5067074  -0.19956549 -0.12420752 -0.08473587]
#  [-0.28235308  0.32039874 -0.25121719 -0.48496054 -0.00638623  0.09450715
#   -0.01043096 -0.10998763 -0.13110891 -0.2499503   0.30922549  0.56820859]
#  [-0.30489082  0.26072642 -0.24644142 -0.51386504 -0.01501558  0.04828636
#    0.03594358 -0.11458725  0.12733269  0.25469473 -0.29762884 -0.57238755]
#  [ 0.41828941  0.11503339  0.14911843 -0.2461236  -0.128042   -0.06488546
#    0.21060526 -0.02328433 -0.07087413  0.75307869  0.04285616  0.29916424]
#  [ 0.39961541  0.27149205  0.03301841 -0.08921454  0.05266549  0.16358923
#   -0.28859676  0.00827937 -0.28266563 -0.24492867 -0.69275428  0.15767056]]

# %%
total = sum(eig_vals)
var_exp = [(i/total)*100 for i in sorted(eig_vals, reverse = True)]
var_exp
# Out:
# [38.579072787998015,
#  20.44137882381034,
#  14.021986979541412,
#  8.781846170776344,
#  6.704434687616163,
#  4.3514924829840345,
#  2.8783943669668135,
#  2.497481224758705,
#  0.948729469371631,
#  0.3242409409389871,
#  0.25392651928304666,
#  0.21701554595452138]

# %%
cum_var_exp = np.cumsum(var_exp)
cum_var_exp
# Out:
# array([ 38.57907279,  59.02045161,  73.04243859,  81.82428476,
#         88.52871945,  92.88021193,  95.7586063 ,  98.25608752,
#         99.20481699,  99.52905793,  99.78298445, 100.        ])

# %%
per_var = np.round(cum_var_exp, decimals = 1) 
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]

plt.figure(figsize = (12, 6))
sns.lineplot(y = var_exp, x = range(1, len(var_exp)+1), marker = 'o')
plt.ylabel('Percentage of Explained Varience')
plt.xlabel('Principal Componenet')
plt.title('Scree Plot')
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 5, random_state = 123)
df_pca = pca.fit_transform(data_std)
df_pca
# Out:
# array([[ 1.33343023,  0.9783068 , -0.43150728, -1.40728292,  0.23016505],
#        [ 1.2074841 , -0.30505733, -0.66455758, -2.08476977,  0.61272123],
#        [ 2.19550157,  0.65569404, -1.0727134 , -1.20804427,  0.26071499],
#        ...,
#        [-0.21255022, -1.79145365, -1.00123892, -1.01431274,  0.97282216],
#        [ 0.11267899, -2.01287084, -0.72502347, -0.88069416,  0.90354411],
#        [-0.02547786, -0.47783594, -0.76199601,  0.1564061 ,  0.09059633]])

# %%
df_pca.transpose()
# Out:
# array([[ 1.33343023,  1.2074841 ,  2.19550157, ..., -0.21255022,
#          0.11267899, -0.02547786],
#        [ 0.9783068 , -0.30505733,  0.65569404, ..., -1.79145365,
#         -2.01287084, -0.47783594],
#        [-0.43150728, -0.66455758, -1.0727134 , ..., -1.00123892,
#         -0.72502347, -0.76199601],
#        [-1.40728292, -2.08476977, -1.20804427, ..., -1.01431274,
#         -0.88069416,  0.1564061 ],
#        [ 0.23016505,  0.61272123,  0.26071499, ...,  0.97282216,
#          0.90354411,  0.09059633]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.38579073, 0.20441379, 0.14021987, 0.08781846, 0.06704435])

# %%
data_std = pd.DataFrame(data_std, columns = list(df_num))
data_std
# Out:
#          MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0       0.189757 -0.044575 -0.203581       0.307739      0.673596
# 1      -0.752786  0.265794 -0.275097       0.307739     -1.131913
# 2       0.111212  0.350440 -0.275097       0.460168      0.560752
# 3      -0.470023  0.674917 -0.275097      -1.216548     -0.342003
# 4       0.833828  1.281548 -0.155903       0.079096     -0.793380
# ...          ...       ...       ...            ...           ...
# 145455 -1.475402  0.025964 -0.275097      -0.683048     -0.116314
# 145456 -1.349730  0.294010 -0.275097      -1.368977     -0.116314
# 145457 -1.066967  0.519733 -0.275097      -0.225761     -0.567692
# 145458 -0.689950  0.533840 -0.275097      -0.911691     -0.116314
# 145459  0.425393 -0.086898 -0.275097      -0.073333      0.335063
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0           0.611499     0.111308    -1.443652    -1.478015    -1.223012
# 1           0.382054    -1.320650    -1.297105    -1.047010    -1.117969
# 2           0.840944    -1.638863    -1.052860    -1.492877    -0.982915
# 3          -1.109339    -1.267615    -1.736746    -0.006653    -0.367666
# 4           0.152609     0.694699    -0.906314    -1.017286    -1.388078
# ...              ...          ...          ...          ...          ...
# 145455     -0.879894    -0.949402    -1.345954     1.033703     0.757789
# 145456     -1.109339    -0.684224    -1.492501     0.870219     0.577716
# 145457     -1.109339    -0.843331    -1.345954     0.498663     0.232577
# 145458     -1.338784    -0.949402    -1.345954     0.260867     0.187559
# 145459     -0.191559    -0.366011    -0.759767     0.379765     0.397644
#
#          Temp9am   Temp3pm
# 0      -0.013506  0.019135
# 1       0.033011  0.384064
# 2       0.622225  0.223495
# 3       0.172562  0.705202
# 4       0.126045  1.172312
# ...          ...       ...
# 145455 -1.067887  0.106718
# 145456 -0.943842  0.413259
# 145457 -0.695753  0.646814
# 145458 -0.292607  0.632217
# 145459 -0.308112 -0.112240
#
# [145460 rows x 12 columns]

# %%
comp = pca.components_
data_loading = pd.DataFrame(comp, columns = list(data_std))
data_loading
# Out:
#     MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0  0.371778  0.410842 -0.001305       0.176627      0.136228      0.147805
# 1 -0.013148 -0.245087  0.232061       0.459042      0.369510      0.411830
# 2  0.274042  0.056430  0.320999      -0.269094     -0.358280     -0.285608
# 3  0.348299  0.093885  0.314306       0.028539      0.269100      0.208707
# 4 -0.214366  0.012753  0.851402       0.014674      0.017784     -0.189542
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm   Temp9am   Temp3pm
# 0    -0.275067    -0.195922    -0.282353    -0.304891  0.418289  0.399615
# 1     0.150304     0.298128    -0.320399    -0.260726 -0.115033 -0.271492
# 2     0.440816     0.441406    -0.251217    -0.246441  0.149118  0.033018
# 3     0.117752     0.269540     0.484961     0.513865  0.246124  0.089215
# 4    -0.189532    -0.370385    -0.006386    -0.015016 -0.128042  0.052665

# %%
from matplotlib.patches import Rectangle
fig, ax = plt.subplots(figsize = (22, 10), facecolor='w', edgecolor = 'k')
ax = sns.heatmap(data_loading, annot = True, fmt = '.2g', cbar = False, ax = ax, vmax = 1.0, vmin = 0.0, cmap = 'Blues', yticklabels = ['PC0', 'PC1', 'PC2', 'PC3', 'PC4'])

columns_max = data_loading.abs().idxmax(axis = 0)

for col, variable in enumerate(data_loading.columns):
    position = data_loading.index.get_loc(columns_max[variable])
    ax.add_patch(Rectangle((col, position), 1,1, fill = False, edgecolor = 'red', lw=3))
plt.show()

# %%
df_pca = pd.DataFrame(df_pca, columns = ['pc_Temp9am', 'pc_WinGustSpeed', 'pc_Humidity3pm', 'pc_Pressure3pm', 'pc_Rainfall'])
df_pca
# Out:
#         pc_Temp9am  pc_WinGustSpeed  pc_Humidity3pm  pc_Pressure3pm  \
# 0         1.333430         0.978307       -0.431507       -1.407283
# 1         1.207484        -0.305057       -0.664558       -2.084770
# 2         2.195502         0.655694       -1.072713       -1.208044
# 3         0.834379        -2.186368       -0.596390       -1.249247
# 4         1.983283        -0.365947        1.031484       -1.051158
# ...            ...              ...             ...             ...
# 145455   -1.206141        -1.748566       -1.629157       -0.669530
# 145456   -0.973143        -2.227271       -1.163206       -0.790269
# 145457   -0.212550        -1.791454       -1.001239       -1.014313
# 145458    0.112679        -2.012871       -0.725023       -0.880694
# 145459   -0.025478        -0.477836       -0.761996        0.156406
#
#         pc_Rainfall
# 0          0.230165
# 1          0.612721
# 2          0.260715
# 3          0.965605
# 4         -0.060053
# ...             ...
# 145455     1.039912
# 145456     1.057843
# 145457     0.972822
# 145458     0.903544
# 145459     0.090596
#
# [145460 rows x 5 columns]

# %%
df_obj
# Out:
#               Date Location WindGustDir WindDir9am WindDir3pm RainToday  \
# 0       2008-12-01   Albury           W          W        WNW        No
# 1       2008-12-02   Albury         WNW        NNW        WSW        No
# 2       2008-12-03   Albury         WSW          W        WSW        No
# 3       2008-12-04   Albury          NE         SE          E        No
# 4       2008-12-05   Albury           W        ENE         NW        No
# ...            ...      ...         ...        ...        ...       ...
# 145455  2017-06-21    Uluru           E         SE        ENE        No
# 145456  2017-06-22    Uluru         NNW         SE          N        No
# 145457  2017-06-23    Uluru           N         SE        WNW        No
# 145458  2017-06-24    Uluru          SE        SSE          N        No
# 145459  2017-06-25    Uluru           W        ESE        ESE        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459           No
#
# [145460 rows x 7 columns]

# %%
df_obj['Location'] = df['Location'].astype('category')
df_obj['WindGustDir'] = df['WindGustDir'].astype('category')
df_obj['WindDir9am'] = df['WindDir9am'].astype('category')
df_obj['WindDir3pm'] = df['WindDir3pm'].astype('category')
# Out:
# <ipython-input-27-f4df47c8405a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obj['Location'] = df['Location'].astype('category')
# <ipython-input-27-f4df47c8405a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obj['WindGustDir'] = df['WindGustDir'].astype('category')
# <ipython-input-27-f4df47c8405a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obj['WindDir9am'] = df['WindDir9am'].astype('category')
# <ipython-input-27-f4df47c8405a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obj['WindDir3pm'] = df['WindDir3pm'].astype('category')

# %%
df_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          145460 non-null  object
#  1   Location      145460 non-null  category
#  2   WindGustDir   135134 non-null  category
#  3   WindDir9am    134894 non-null  category
#  4   WindDir3pm    141232 non-null  category
#  5   RainToday     145460 non-null  object
#  6   RainTomorrow  145460 non-null  object
# dtypes: category(4), object(3)
# memory usage: 3.9+ MB

# %%
df_obj
# Out:
#               Date Location WindGustDir WindDir9am WindDir3pm RainToday  \
# 0       2008-12-01   Albury           W          W        WNW        No
# 1       2008-12-02   Albury         WNW        NNW        WSW        No
# 2       2008-12-03   Albury         WSW          W        WSW        No
# 3       2008-12-04   Albury          NE         SE          E        No
# 4       2008-12-05   Albury           W        ENE         NW        No
# ...            ...      ...         ...        ...        ...       ...
# 145455  2017-06-21    Uluru           E         SE        ENE        No
# 145456  2017-06-22    Uluru         NNW         SE          N        No
# 145457  2017-06-23    Uluru           N         SE        WNW        No
# 145458  2017-06-24    Uluru          SE        SSE          N        No
# 145459  2017-06-25    Uluru         NaN        ESE        ESE        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459           No
#
# [145460 rows x 7 columns]

# %%
df_obj=df_obj.drop('Date', axis = 1)

# %%
df_obj['Location'] = df_obj['Location'].cat.codes
df_obj['WindGustDir'] = df_obj['WindGustDir'].cat.codes
df_obj['WindDir9am'] = df_obj['WindDir9am'].cat.codes
df_obj['WindDir3pm'] = df_obj['WindDir3pm'].cat.codes

# %%
df_obj['RainToday'] = pd.get_dummies(df_obj['RainToday'], drop_first = True)
df_obj['RainTomorrow'] = pd.get_dummies(df_obj['RainTomorrow'], drop_first = True)

# %%
df_obj
# Out:
#         Location  WindGustDir  WindDir9am  WindDir3pm  RainToday  RainTomorrow
# 0              2           13          13          14          0             0
# 1              2           14           6          15          0             0
# 2              2           15          13          15          0             0
# 3              2            4           9           0          0             0
# 4              2           13           1           7          0             0
# ...          ...          ...         ...         ...        ...           ...
# 145455        41            0           9           1          0             0
# 145456        41            6           9           3          0             0
# 145457        41            3           9          14          0             0
# 145458        41            9          10           3          0             0
# 145459        41           -1           2           2          0             0
#
# [145460 rows x 6 columns]

# %%
df_ml = pd.concat([df_pca, df_obj], axis = 1, join = 'inner')
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   pc_Temp9am       145460 non-null  float64
#  1   pc_WinGustSpeed  145460 non-null  float64
#  2   pc_Humidity3pm   145460 non-null  float64
#  3   pc_Pressure3pm   145460 non-null  float64
#  4   pc_Rainfall      145460 non-null  float64
#  5   Location         145460 non-null  int8
#  6   WindGustDir      145460 non-null  int8
#  7   WindDir9am       145460 non-null  int8
#  8   WindDir3pm       145460 non-null  int8
#  9   RainToday        145460 non-null  uint8
#  10  RainTomorrow     145460 non-null  uint8
# dtypes: float64(5), int8(4), uint8(2)
# memory usage: 6.4 MB

# %%
df_ml
# Out:
#         pc_Temp9am  pc_WinGustSpeed  pc_Humidity3pm  pc_Pressure3pm  \
# 0         1.333430         0.978307       -0.431507       -1.407283
# 1         1.207484        -0.305057       -0.664558       -2.084770
# 2         2.195502         0.655694       -1.072713       -1.208044
# 3         0.834379        -2.186368       -0.596390       -1.249247
# 4         1.983283        -0.365947        1.031484       -1.051158
# ...            ...              ...             ...             ...
# 145455   -1.206141        -1.748566       -1.629157       -0.669530
# 145456   -0.973143        -2.227271       -1.163206       -0.790269
# 145457   -0.212550        -1.791454       -1.001239       -1.014313
# 145458    0.112679        -2.012871       -0.725023       -0.880694
# 145459   -0.025478        -0.477836       -0.761996        0.156406
#
#         pc_Rainfall  Location  WindGustDir  WindDir9am  WindDir3pm  RainToday  \
# 0          0.230165         2           13          13          14          0
# 1          0.612721         2           14           6          15          0
# 2          0.260715         2           15          13          15          0
# 3          0.965605         2            4           9           0          0
# 4         -0.060053         2           13           1           7          0
# ...             ...       ...          ...         ...         ...        ...
# 145455     1.039912        41            0           9           1          0
# 145456     1.057843        41            6           9           3          0
# 145457     0.972822        41            3           9          14          0
# 145458     0.903544        41            9          10           3          0
# 145459     0.090596        41           -1           2           2          0
#
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 145455             0
# 145456             0
# 145457             0
# 145458             0
# 145459             0
#
# [145460 rows x 11 columns]

# %%
x = df_ml.drop('RainTomorrow', axis = 1)
x = np.array(x,type(int))
x
# Out:
# array([[1.333430227088968, 0.9783067984552734, -0.4315072773073193, ...,
#         13.0, 14.0, 0.0],
#        [1.2074841001743266, -0.30505732740181857, -0.6645575796465738,
#         ..., 6.0, 15.0, 0.0],
#        [2.1955015741905255, 0.655694039934838, -1.0727134013744306, ...,
#         13.0, 15.0, 0.0],
#        ...,
#        [-0.2125502189246755, -1.7914536462357369, -1.0012389211954564,
#         ..., 9.0, 14.0, 0.0],
#        [0.11267898759439256, -2.012870842165029, -0.7250234657420661,
#         ..., 10.0, 3.0, 0.0],
#        [-0.025477857203059107, -0.4778359412015698, -0.7619960097462818,
#         ..., 2.0, 2.0, 0.0]], dtype=object)

# %%
y = df_ml.pop('RainTomorrow')
y = np.array(y,type(int))
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=object)

# %%
rand = np.random.RandomState(0)
indices = np.arange(len(df_ml))
rand.shuffle(indices)

# %%
x1 = x[indices[:10390]]
y1 = y[indices[:10390]]

# %%
x1=x1.astype('float')
y1=y1.astype('float')

# %%
x_component, y_component = x1[:, 0], x1[:, 1]

# %%
X_pool = x1
y_pool = y1

# %%
n_labeled_examples = x1.shape[0]
training_indices = np.random.randint(low=0, high=n_labeled_examples + 1, size=10)

X_train = x1[training_indices]
y_train = y1[training_indices]


X_pool = np.delete(x1, training_indices, axis=0)
y_pool = np.delete(y1, training_indices, axis=0)

# %%
def random_sampling(logreg, X_pool):
    n_samples = len(X_pool)
    query_idx = np.random.choice(range(n_samples))
    return query_idx, X_pool[query_idx]

# %%
from sklearn.linear_model import LogisticRegression
from modAL.models import ActiveLearner

logreg = LogisticRegression(solver = 'liblinear')
learner = ActiveLearner(estimator=logreg,query_strategy=random_sampling, X_training=x1, y_training=y1)

# %%
predictions = learner.predict(x1)
is_correct = (predictions == y1)

predictions
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
unqueried_score = learner.score(x1, y1)

fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)
ax.scatter(x=x_component[is_correct],  y=y_component[is_correct],  c='g', marker='+', label='Correct',   alpha=8/10)
ax.scatter(x=x_component[~is_correct], y=y_component[~is_correct], c='r', marker='x', label='Incorrect', alpha=8/10)
ax.legend(loc='lower right')
ax.set_title("Random Sampling Predictions (Accuracy: {score:.3f})".format(score=unqueried_score))
plt.savefig('C:\\Users\\pod2g\\Desktop\\AI 6.5\\Random3.png')
plt.show()

# %%
N_QUERIES = 200
performance_history = [unqueried_score]

for index in range(N_QUERIES):
    query_index, query_instance = learner.query(X_pool)
    
    X,y = X_pool[query_index].reshape(1,-1), y_pool[query_index].reshape(1, )
    learner.teach(X = X, y = y)
    
    X_pool, y_pool = np.delete(X_pool, query_index, axis = 0), np.delete(y_pool, query_index)
    model_accuracy = learner.score(x1, y1)
    print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
    
    performance_history.append(model_accuracy)
# Out:
# Accuracy after query 1: 0.8274
# Accuracy after query 2: 0.8275
# Accuracy after query 3: 0.8276
# Accuracy after query 4: 0.8275
# Accuracy after query 5: 0.8275
# Accuracy after query 6: 0.8274
# Accuracy after query 7: 0.8273
# Accuracy after query 8: 0.8274
# Accuracy after query 9: 0.8274
# Accuracy after query 10: 0.8274
# Accuracy after query 11: 0.8273
# Accuracy after query 12: 0.8275
# Accuracy after query 13: 0.8274
# Accuracy after query 14: 0.8274
# Accuracy after query 15: 0.8274
# Accuracy after query 16: 0.8273
# Accuracy after query 17: 0.8272
# Accuracy after query 18: 0.8272
# Accuracy after query 19: 0.8272
# Accuracy after query 20: 0.8271
# Accuracy after query 21: 0.8271
# Accuracy after query 22: 0.8271
# Accuracy after query 23: 0.8274
# Accuracy after query 24: 0.8274
# Accuracy after query 25: 0.8274
# Accuracy after query 26: 0.8272
# Accuracy after query 27: 0.8273
# Accuracy after query 28: 0.8274
# Accuracy after query 29: 0.8274
# Accuracy after query 30: 0.8272
# Accuracy after query 31: 0.8274
# Accuracy after query 32: 0.8274
# Accuracy after query 33: 0.8273
# Accuracy after query 34: 0.8273
# Accuracy after query 35: 0.8273
# Accuracy after query 36: 0.8273
# Accuracy after query 37: 0.8274
# Accuracy after query 38: 0.8274
# Accuracy after query 39: 0.8270
# Accuracy after query 40: 0.8270
# Accuracy after query 41: 0.8270
# Accuracy after query 42: 0.8270
# Accuracy after query 43: 0.8270
# Accuracy after query 44: 0.8270
# Accuracy after query 45: 0.8270
# Accuracy after query 46: 0.8271
# Accuracy after query 47: 0.8271
# Accuracy after query 48: 0.8271
# Accuracy after query 49: 0.8272
# Accuracy after query 50: 0.8272
# Accuracy after query 51: 0.8273
# Accuracy after query 52: 0.8273
# Accuracy after query 53: 0.8273
# Accuracy after query 54: 0.8272
# Accuracy after query 55: 0.8272
# Accuracy after query 56: 0.8272
# Accuracy after query 57: 0.8272
# Accuracy after query 58: 0.8272
# Accuracy after query 59: 0.8272
# Accuracy after query 60: 0.8272
# Accuracy after query 61: 0.8272
# Accuracy after query 62: 0.8272
# Accuracy after query 63: 0.8272
# Accuracy after query 64: 0.8272
# Accuracy after query 65: 0.8272
# Accuracy after query 66: 0.8272
# Accuracy after query 67: 0.8272
# Accuracy after query 68: 0.8272
# Accuracy after query 69: 0.8272
# Accuracy after query 70: 0.8272
# Accuracy after query 71: 0.8272
# Accuracy after query 72: 0.8272
# Accuracy after query 73: 0.8272
# Accuracy after query 74: 0.8274
# Accuracy after query 75: 0.8274
# Accuracy after query 76: 0.8271
# Accuracy after query 77: 0.8271
# Accuracy after query 78: 0.8269
# Accuracy after query 79: 0.8269
# Accuracy after query 80: 0.8271
# Accuracy after query 81: 0.8271
# Accuracy after query 82: 0.8271
# Accuracy after query 83: 0.8272
# Accuracy after query 84: 0.8271
# Accuracy after query 85: 0.8272
# Accuracy after query 86: 0.8271
# Accuracy after query 87: 0.8271
# Accuracy after query 88: 0.8272
# Accuracy after query 89: 0.8271
# Accuracy after query 90: 0.8271
# Accuracy after query 91: 0.8272
# Accuracy after query 92: 0.8272
# Accuracy after query 93: 0.8271
# Accuracy after query 94: 0.8271
# Accuracy after query 95: 0.8271
# Accuracy after query 96: 0.8271
# Accuracy after query 97: 0.8271
# Accuracy after query 98: 0.8271
# Accuracy after query 99: 0.8272
# Accuracy after query 100: 0.8272
# Accuracy after query 101: 0.8272
# Accuracy after query 102: 0.8272
# Accuracy after query 103: 0.8272
# Accuracy after query 104: 0.8271
# Accuracy after query 105: 0.8271
# Accuracy after query 106: 0.8271
# Accuracy after query 107: 0.8272
# Accuracy after query 108: 0.8273
# Accuracy after query 109: 0.8273
# Accuracy after query 110: 0.8273
# Accuracy after query 111: 0.8273
# Accuracy after query 112: 0.8273
# Accuracy after query 113: 0.8274
# Accuracy after query 114: 0.8274
# Accuracy after query 115: 0.8273
# Accuracy after query 116: 0.8273
# Accuracy after query 117: 0.8273
# Accuracy after query 118: 0.8273
# Accuracy after query 119: 0.8272
# Accuracy after query 120: 0.8273
# Accuracy after query 121: 0.8273
# Accuracy after query 122: 0.8273
# Accuracy after query 123: 0.8273
# Accuracy after query 124: 0.8272
# Accuracy after query 125: 0.8272
# Accuracy after query 126: 0.8272
# Accuracy after query 127: 0.8272
# Accuracy after query 128: 0.8272
# Accuracy after query 129: 0.8272
# Accuracy after query 130: 0.8272
# Accuracy after query 131: 0.8272
# Accuracy after query 132: 0.8273
# Accuracy after query 133: 0.8273
# Accuracy after query 134: 0.8273
# Accuracy after query 135: 0.8273
# Accuracy after query 136: 0.8274
# Accuracy after query 137: 0.8274
# Accuracy after query 138: 0.8274
# Accuracy after query 139: 0.8274
# Accuracy after query 140: 0.8274
# Accuracy after query 141: 0.8274
# Accuracy after query 142: 0.8274
# Accuracy after query 143: 0.8274
# Accuracy after query 144: 0.8273
# Accuracy after query 145: 0.8270
# Accuracy after query 146: 0.8271
# Accuracy after query 147: 0.8271
# Accuracy after query 148: 0.8270
# Accuracy after query 149: 0.8271
# Accuracy after query 150: 0.8271
# Accuracy after query 151: 0.8270
# Accuracy after query 152: 0.8271
# Accuracy after query 153: 0.8271
# Accuracy after query 154: 0.8271
# Accuracy after query 155: 0.8271
# Accuracy after query 156: 0.8271
# Accuracy after query 157: 0.8272
# Accuracy after query 158: 0.8272
# Accuracy after query 159: 0.8272
# Accuracy after query 160: 0.8272
# Accuracy after query 161: 0.8272
# Accuracy after query 162: 0.8272
# Accuracy after query 163: 0.8272
# Accuracy after query 164: 0.8273
# Accuracy after query 165: 0.8273
# Accuracy after query 166: 0.8273
# Accuracy after query 167: 0.8273
# Accuracy after query 168: 0.8273
# Accuracy after query 169: 0.8273
# Accuracy after query 170: 0.8273
# Accuracy after query 171: 0.8273
# Accuracy after query 172: 0.8272
# Accuracy after query 173: 0.8273
# Accuracy after query 174: 0.8273
# Accuracy after query 175: 0.8273
# Accuracy after query 176: 0.8273
# Accuracy after query 177: 0.8273
# Accuracy after query 178: 0.8273
# Accuracy after query 179: 0.8273
# Accuracy after query 180: 0.8273
# Accuracy after query 181: 0.8273
# Accuracy after query 182: 0.8273
# Accuracy after query 183: 0.8273
# Accuracy after query 184: 0.8273
# Accuracy after query 185: 0.8273
# Accuracy after query 186: 0.8272
# Accuracy after query 187: 0.8272
# Accuracy after query 188: 0.8272
# Accuracy after query 189: 0.8272
# Accuracy after query 190: 0.8272
# Accuracy after query 191: 0.8271
# Accuracy after query 192: 0.8272
# Accuracy after query 193: 0.8273
# Accuracy after query 194: 0.8272
# Accuracy after query 195: 0.8273
# Accuracy after query 196: 0.8274
# Accuracy after query 197: 0.8274
# Accuracy after query 198: 0.8275
# Accuracy after query 199: 0.8274
# Accuracy after query 200: 0.8274

# %%
fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)

ax.plot(performance_history)
ax.scatter(range(len(performance_history)), performance_history, s=13)

ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=5, integer=True))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=10))
ax.yaxis.set_major_formatter(mpl.ticker.PercentFormatter(xmax=1))

ax.set_ylim(bottom=0.5, top=1)
ax.grid(True)

ax.set_title('Classification Accuracy')
ax.set_xlabel('Query iteration')
ax.set_ylabel('Classification Accuracy')
plt.savefig('C:\\Users\\pod2g\\Desktop\\AI 6.5\\Random1.png')

plt.show()

# %%
predictions = learner.predict(x1)
is_correct = (predictions == y1)


fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)

ax.scatter(x=x_component[is_correct],  y=y_component[is_correct],  c='g', marker='+', label='Correct',   alpha=8/10)
ax.scatter(x=x_component[~is_correct], y=y_component[~is_correct], c='r', marker='x', label='Incorrect', alpha=8/10)


ax.set_title('Random Sampling Classification Accuracy after {n} queries: {final_acc:.3f}'.format(n=N_QUERIES, final_acc=performance_history[-1]))
ax.legend(loc='lower right')
plt.savefig('C:\\Users\\pod2g\\Desktop\\AI 6.5\\Random2.png')

plt.show()
